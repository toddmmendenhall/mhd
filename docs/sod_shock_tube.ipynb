# %%
import matplotlib.pyplot as plt
import numpy as np

for i in range(0, 100, 5):
    filename = f'../build/results_{i}.csv'
    data = np.loadtxt(filename, delimiter=',')
    rho = data.transpose()[0]
    plt.plot(rho, 'o--')

plt.show()
