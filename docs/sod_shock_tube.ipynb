# %%
import matplotlib.pyplot as plt
import numpy as np

for i in range(100):
    filename = f'../build/results_{i}.csv'
    data = np.loadtxt(filename, delimiter=',')
    rho = data.transpose()[4][:-2]
    plt.plot(rho, '--')

plt.show()
