# %%
import matplotlib.pyplot as plt
import numpy as np

for i in [0, 1, 2]:
    filename = f'../build/results_{i}.csv'
    data = np.loadtxt(filename, delimiter=',')
    # x = data.transpose()[0]
    rho = data.transpose()[1][:-6]
    plt.plot(rho, '.--')
plt.grid()

# plt.ylim(-100, 100)
plt.show()
