# %%
import matplotlib.pyplot as plt
import numpy as np

for i in [0, 1, 100]:
    filename = f'../build/results_{i}.csv'
    data = np.loadtxt(filename, delimiter=',')
    rho = data.transpose()[5]
    plt.plot(rho, '.--')

plt.show()
