# %%
import matplotlib.pyplot as plt
import numpy as np

for i in range(6):
    filename = f'../build/results_{i}.csv'
    data = np.loadtxt(filename, delimiter=',', skiprows=2)
    rho = data.transpose()[6]
    plt.plot(rho, '.--')

plt.show()
