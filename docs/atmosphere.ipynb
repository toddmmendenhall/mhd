# %%
import matplotlib.pyplot as plt
import numpy as np

for i in [0, 686]:
    filename = f'../build/results_{i}.csv'
    data = np.loadtxt(filename, delimiter=',')
    rho = data.transpose()[8]
    plt.plot(rho, '.--')

plt.show()
