# %%
import matplotlib.pyplot as plt
import numpy as np

for i in range(7):
    filename = f'../build/results_{i}.csv'
    data = np.loadtxt(filename, delimiter=',', skiprows=2)
    x = data.transpose()[0]
    rho = data.transpose()[1]
    plt.plot(x, rho, '.--')

plt.show()
