# %%
import matplotlib.pyplot as plt
import numpy as np

for i in range(66):
    filename = f'../build/test/results_{i}.csv'
    data = np.loadtxt(filename, delimiter=',', skiprows=2)
    x = data.transpose()[0][:-2]
    rho = data.transpose()[2][:-2]
    plt.plot(x, rho, '--')

plt.show()
